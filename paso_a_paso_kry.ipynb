# %%
"""import pandas as pd

# Leer solo las primeras 5 filas para verificar encabezados
df_preview = pd.read_csv('tu_archivo.csv', nrows=5)
print(df_preview.columns)

# Si el archivo es muy pesado, carga solo las columnas que necesitas para las gráficas
cols_interes = ['pCut::Motor_Torque', 'pCut::CTRL_Position_controller::Lag_error', 'mode']
df = pd.read_csv('tu_archivo.csv', usecols=cols_interes)
"""
