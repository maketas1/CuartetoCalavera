# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1 = pd.read_csv('One_year_compiled.csv')

# %% [markdown]
# # Ejercicio 1

# %%
df1.columns
# Out:
# Index(['timestamp', 'pCut::Motor_Torque',
#        'pCut::CTRL_Position_controller::Lag_error',
#        'pCut::CTRL_Position_controller::Actual_position',
#        'pCut::CTRL_Position_controller::Actual_speed',
#        'pSvolFilm::CTRL_Position_controller::Actual_position',
#        'pSvolFilm::CTRL_Position_controller::Actual_speed',
#        'pSvolFilm::CTRL_Position_controller::Lag_error', 'pSpintor::VAX_speed',
#        'month', 'day', 'hour', 'sample_Number', 'mode'],
#       dtype='str')

# %%
df1['mode'].unique()
# Out:
# <StringArray>
# ['mode1', 'mode2', 'mode5', 'mode3', 'mode4', 'mode8', 'mode6', 'mode7']
# Length: 8, dtype: str

# %%
df1.head()
# Out:
#    timestamp  pCut::Motor_Torque  pCut::CTRL_Position_controller::Lag_error  \
# 0      0.008            0.199603                                   0.027420
# 1      0.012            0.281624                                   0.002502
# 2      0.016            0.349315                                  -0.018085
# 3      0.020            0.444450                                  -0.054680
# 4      0.024            0.480923                                  -0.042770
#
#    pCut::CTRL_Position_controller::Actual_position  \
# 0                                        628392628
# 1                                        628392625
# 2                                        628392621
# 3                                        628392617
# 4                                        628392613
#
#    pCut::CTRL_Position_controller::Actual_speed  \
# 0                                   -920.104980
# 1                                   -937.271118
# 2                                   -951.004028
# ...

# %%
# pd.set_option('display.float_format', '{:.2f}'.format)
df1.describe().round(3)
# Out:
#          timestamp  pCut::Motor_Torque  \
# count  1062912.000         1062912.000
# mean         4.102              -0.121
# std          2.365               0.608
# min          0.004              -6.560
# 25%          2.056              -0.370
# 50%          4.104              -0.119
# 75%          6.152               0.255
# max          8.200               3.857
#
#        pCut::CTRL_Position_controller::Lag_error  \
# count                                1062912.000
# mean                                      -0.000
# std                                        0.121
# min                                       -1.888
# 25%                                       -0.022
# 50%                                        0.001
# 75%                                        0.024
# max                                        2.022
#
#        pCut::CTRL_Position_controller::Actual_position  \
# count                                     1.062912e+06
# ...

# %%
# pd.set_option('display.max_rows', None)
df1['hour'].value_counts(ascending=True)
# Out:
# hour
# 185909.0    1530
# 184148.0    2049
# 184424.0    2049
# 184835.0    2049
# 185047.0    2049
#             ...
# 151444.0    2049
# 155353.0    2049
# 183459.0    2049
# 121536.0    4098
# 113211.0    4098
# Name: count, Length: 517, dtype: int64

# %% [markdown]
# # Ejercicio 3

# %%
df1_copia = df1.copy()
df1_copia
# Out:
#          timestamp  pCut::Motor_Torque  \
# 0         0.008000            0.199603
# 1         0.012000            0.281624
# 2         0.016000            0.349315
# 3         0.020000            0.444450
# 4         0.024000            0.480923
# ...            ...                 ...
# 1062907   8.179999           -0.277697
# 1062908   8.183999           -0.285098
# 1062909   8.187999           -0.155192
# 1062910   8.191999           -0.371426
# 1062911   8.195999           -0.284030
#
#          pCut::CTRL_Position_controller::Lag_error  \
# 0                                         0.027420
# 1                                         0.002502
# 2                                        -0.018085
# 3                                        -0.054680
# 4                                        -0.042770
# ...                                            ...
# 1062907                                  -0.023948
# 1062908                                  -0.022138
# ...

# %% [markdown]
# # Ejercicio 4

# %%
df1_copia.select_dtypes(include=["str"])
# Out:
#           mode
# 0        mode1
# 1        mode1
# 2        mode1
# 3        mode1
# 4        mode1
# ...        ...
# 1062907  mode2
# 1062908  mode2
# 1062909  mode2
# 1062910  mode2
# 1062911  mode2
#
# [1062912 rows x 1 columns]

# %% [markdown]
# # Ejercicio 5

# %%
df1.drop(columns=["day"])
# Out:
#          timestamp  pCut::Motor_Torque  \
# 0         0.008000            0.199603
# 1         0.012000            0.281624
# 2         0.016000            0.349315
# 3         0.020000            0.444450
# 4         0.024000            0.480923
# ...            ...                 ...
# 1062907   8.179999           -0.277697
# 1062908   8.183999           -0.285098
# 1062909   8.187999           -0.155192
# 1062910   8.191999           -0.371426
# 1062911   8.195999           -0.284030
#
#          pCut::CTRL_Position_controller::Lag_error  \
# 0                                         0.027420
# 1                                         0.002502
# 2                                        -0.018085
# 3                                        -0.054680
# 4                                        -0.042770
# ...                                            ...
# 1062907                                  -0.023948
# 1062908                                  -0.022138
# ...

# %% [markdown]
# # Ejercicio 6

# %%
df1_copia["nueva"] = df1_copia["month"].values * 2
df1_copia
# Out:
#          timestamp  pCut::Motor_Torque  \
# 0         0.008000            0.199603
# 1         0.012000            0.281624
# 2         0.016000            0.349315
# 3         0.020000            0.444450
# 4         0.024000            0.480923
# ...            ...                 ...
# 1062907   8.179999           -0.277697
# 1062908   8.183999           -0.285098
# 1062909   8.187999           -0.155192
# 1062910   8.191999           -0.371426
# 1062911   8.195999           -0.284030
#
#          pCut::CTRL_Position_controller::Lag_error  \
# 0                                         0.027420
# 1                                         0.002502
# 2                                        -0.018085
# 3                                        -0.054680
# 4                                        -0.042770
# ...                                            ...
# 1062907                                  -0.023948
# 1062908                                  -0.022138
# ...

# %% [markdown]
# # Ejercicio 7

# %%
df1_copia.loc[500:750, "month" : "nueva"]
# Out:
#      month  day      hour  sample_Number   mode  nueva
# 500      1    4  184148.0            0.0  mode1      2
# 501      1    4  184148.0            0.0  mode1      2
# 502      1    4  184148.0            0.0  mode1      2
# 503      1    4  184148.0            0.0  mode1      2
# 504      1    4  184148.0            0.0  mode1      2
# ..     ...  ...       ...            ...    ...    ...
# 746      1    4  184148.0            0.0  mode1      2
# 747      1    4  184148.0            0.0  mode1      2
# 748      1    4  184148.0            0.0  mode1      2
# 749      1    4  184148.0            0.0  mode1      2
# 750      1    4  184148.0            0.0  mode1      2
#
# [251 rows x 6 columns]

# %%
df1_copia.iloc[500:751, 1:5]
# Out:
#      pCut::Motor_Torque  pCut::CTRL_Position_controller::Lag_error  \
# 500           -0.131797                                   0.007229
# 501            0.004542                                  -0.019871
# 502           -0.138911                                   0.018225
# 503           -0.136871                                   0.017830
# 504           -0.176290                                   0.017183
# ..                  ...                                        ...
# 746            0.261230                                   0.081220
# 747            0.365543                                   0.057757
# 748            0.292283                                   0.054181
# 749            0.345109                                   0.017140
# 750            0.502149                                  -0.039527
#
#      pCut::CTRL_Position_controller::Actual_position  \
# 500                                        628395807
# ...

# %% [markdown]
# # Ejercicio 8

# %%
consulta = df1_copia["month"] < 6
df1_copia[consulta]
# Out:
#         timestamp  pCut::Motor_Torque  \
# 0           0.008            0.199603
# 1           0.012            0.281624
# 2           0.016            0.349315
# 3           0.020            0.444450
# 4           0.024            0.480923
# ...           ...                 ...
# 581911      1.124           -0.124228
# 581912      1.128           -0.087999
# 581913      1.132           -0.047169
# 581914      1.136           -0.106502
# 581915      1.140           -0.122433
#
#         pCut::CTRL_Position_controller::Lag_error  \
# 0                                        0.027420
# 1                                        0.002502
# 2                                       -0.018085
# 3                                       -0.054680
# 4                                       -0.042770
# ...                                           ...
# 581911                                   0.002363
# 581912                                  -0.008263
# ...

# %% [markdown]
# Duplicados si existen

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
## 7
import seaborn as sns

sns.histplot(
    data=df1, x='pSvolFilm::CTRL_Position_controller::Actual_speed',
    bins=30,              # Número de bins
    binwidth=5,           # Ancho de cada bin (alternativa a bins)
    stat='count',         # count, frequency, probability, percent, density
    kde=True,             # Superponer curva KDE
   # hue='category',       # Color por categoría
    multiple='layer',     # layer, dodge, stack, fill
    element='bars',       # bars, step, poly
    cumulative=False,     # Si True, histograma acumulado
    color='steelblue',    # Color cuando no hay hue
    #palette='Set2',       # Paleta de colores cuando hay hue
    alpha=0.7,            # Transparencia
    linewidth=1,          # Grosor del borde
                    # Axes de Matplotlib donde dibujar
)
# Out:
# <Axes: xlabel='pSvolFilm::CTRL_Position_controller::Actual_speed', ylabel='Count'>

# %%
sns.histplot(
    data=df1, x='pSvolFilm::CTRL_Position_controller::Lag_error',
    bins=30,              # Número de bins
    binwidth=5,           # Ancho de cada bin (alternativa a bins)
    stat='count',         # count, frequency, probability, percent, density
    kde=True,             # Superponer curva KDE
   # hue='category',       # Color por categoría
    multiple='layer',     # layer, dodge, stack, fill
    element='bars',       # bars, step, poly
    cumulative=False,     # Si True, histograma acumulado
    color='steelblue',    # Color cuando no hay hue
    #palette='Set2',       # Paleta de colores cuando hay hue
    alpha=0.7,            # Transparencia
    linewidth=1,          # Grosor del borde
                    # Axes de Matplotlib donde dibujar
)
# Out:
# <Axes: xlabel='pSvolFilm::CTRL_Position_controller::Lag_error', ylabel='Count'>

# %%
sns.histplot(
    data=df1, x='pSpintor::VAX_speed',
    bins=30,              # Número de bins
    binwidth=5,           # Ancho de cada bin (alternativa a bins)
    stat='count',         # count, frequency, probability, percent, density
    kde=True,             # Superponer curva KDE
   #hue='category',       # Color por categoría
    multiple='layer',     # layer, dodge, stack, fill
    element='bars',       # bars, step, poly
    cumulative=False,     # Si True, histograma acumulado
    color='steelblue',    # Color cuando no hay hue
    #palette='Set2',       # Paleta de colores cuando hay hue
    alpha=0.7,            # Transparencia
    linewidth=1,          # Grosor del borde
                    # Axes de Matplotlib donde dibujar
)
# Out:
# <Axes: xlabel='pSpintor::VAX_speed', ylabel='Count'>

# %%
df1_copia['pCut::Motor_Torque'].round(decimals=2)
df1_copia['pCut::CTRL_Position_controller::Lag_error'].round(decimals=2)

print(df1_copia)
# Out:
#          timestamp  pCut::Motor_Torque  \
# 0         0.008000            0.199603
# 1         0.012000            0.281624
# 2         0.016000            0.349315
# 3         0.020000            0.444450
# 4         0.024000            0.480923
# ...            ...                 ...
# 1062907   8.179999           -0.277697
# 1062908   8.183999           -0.285098
# 1062909   8.187999           -0.155192
# 1062910   8.191999           -0.371426
# 1062911   8.195999           -0.284030
#
#          pCut::CTRL_Position_controller::Lag_error  \
# 0                                         0.027420
# 1                                         0.002502
# 2                                        -0.018085
# 3                                        -0.054680
# 4                                        -0.042770
# ...                                            ...
# 1062907                                  -0.023948
# 1062908                                  -0.022138
# ...

# %%
import seaborn as sns

# Primer gráfico

df1 = df1.drop_duplicates(
    subset=[
        'pCut::Motor_Torque',
        'pCut::CTRL_Position_controller::Lag_error'
    ]
).reset_index(drop=True)

sns.relplot(
    data=df1,
    x='pCut::Motor_Torque', 
    y='pCut::CTRL_Position_controller::Lag_error'
)

# %%
# Segundo gráfico

df1 = df1.drop_duplicates(
    subset=[
        'pCut::CTRL_Position_controller::Lag_error',
        'pCut::CTRL_Position_controller::Actual_position'
    ]
).reset_index(drop=True)

sns.relplot(
    data=df1,
    x='pCut::CTRL_Position_controller::Lag_error', 
    y='pCut::CTRL_Position_controller::Actual_position'
)

# %%
# Tercer gráfico

df1 = df1.drop_duplicates(
    subset=[
        'pCut::CTRL_Position_controller::Actual_position',
        'pCut::CTRL_Position_controller::Actual_speed'
    ]
).reset_index(drop=True)

sns.relplot(
    data=df1,
    x='pCut::CTRL_Position_controller::Actual_position', 
    y='pCut::CTRL_Position_controller::Actual_speed'
)

# %%
# Qunito gráfico

df1 = df1.drop_duplicates(
    subset=[
        'pCut::CTRL_Position_controller::Actual_speed',
        'pSvolFilm::CTRL_Position_controller::Actual_position'
    ]
).reset_index(drop=True)

sns.relplot(
    data=df1,
    x='pCut::CTRL_Position_controller::Actual_speed', 
    y='pSvolFilm::CTRL_Position_controller::Actual_position'
)

# %%
df1 = df1.drop_duplicates(
    subset=[
        'pSvolFilm::CTRL_Position_controller::Actual_position',
        'pSvolFilm::CTRL_Position_controller::Lag_error'
    ]
).reset_index(drop=True)

sns.relplot(
    data=df1,
    x='pSvolFilm::CTRL_Position_controller::Actual_position', 
    y='pSvolFilm::CTRL_Position_controller::Lag_error'
)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.rugplot (
    data=df1,
    x='pCut::Motor_Torque',
    height=0.5,      # Altura de las marcas (proporción del eje)
    color='firebrick',
    alpha=0.4,
    ax=ax
)
# Out:
# <Axes: xlabel='pCut::Motor_Torque'>

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.rugplot (
    data=df1,
    x='pCut::CTRL_Position_controller::Lag_error',
    height=0.5,      # Altura de las marcas (proporción del eje)
    color='firebrick',
    alpha=0.4,
    ax=ax
)
# Out:
# <Axes: xlabel='pCut::CTRL_Position_controller::Lag_error'>

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.rugplot (
    data=df1,
    x='pCut::CTRL_Position_controller::Actual_position',
    height=0.5,      # Altura de las marcas (proporción del eje)
    color='firebrick',
    alpha=0.4,
    ax=ax
)
# Out:
# <Axes: xlabel='pCut::CTRL_Position_controller::Actual_position'>

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.rugplot (
    data=df1,
    x='pCut::CTRL_Position_controller::Actual_speed',
    height=0.5,      # Altura de las marcas (proporción del eje)
    color='firebrick',
    alpha=0.4,
    ax=ax
)
# Out:
# <Axes: xlabel='pCut::CTRL_Position_controller::Actual_speed'>

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.rugplot (
    data=df1,
    x='pSvolFilm::CTRL_Position_controller::Actual_position',
    height=0.5,      # Altura de las marcas (proporción del eje)
    color='firebrick',
    alpha=0.4,
    ax=ax
)
# Out:
# <Axes: xlabel='pSvolFilm::CTRL_Position_controller::Actual_position'>

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.rugplot (
    data=df1,
    x='pSvolFilm::CTRL_Position_controller::Actual_speed',
    height=0.5,      # Altura de las marcas (proporción del eje)
    color='firebrick',
    alpha=0.4,
    ax=ax
)
# Out:
# <Axes: xlabel='pSvolFilm::CTRL_Position_controller::Actual_speed'>

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.rugplot (
    data=df1,
    x='pSvolFilm::CTRL_Position_controller::Lag_error',
    height=0.5,      # Altura de las marcas (proporción del eje)
    color='firebrick',
    alpha=0.4,
    ax=ax
)
# Out:
# <Axes: xlabel='pSvolFilm::CTRL_Position_controller::Lag_error'>

# %%
df1_copia["averia"] = (
    (df1_copia["pCut::CTRL_Position_controller::Lag_error"] < 0) |
    (df1_copia["pSvolFilm::CTRL_Position_controller::Lag_error"] < 0) |
    (df1_copia["pCut::CTRL_Position_controller::Lag_error"] > 1.7 ) |
    (df1_copia["pSvolFilm::CTRL_Position_controller::Lag_error"] > 3 )
).astype(int)

df1_copia["averia"].value_counts()

df1_copia["s1"] = (
    (df1_copia["pCut::CTRL_Position_controller::Lag_error"] < 0 ) |
    (df1_copia["pCut::CTRL_Position_controller::Lag_error"] > 1.7 )
).astype(int)

df1_copia["s1"].value_counts()

df1_copia["s2"] = (
    (df1_copia["pSvolFilm::CTRL_Position_controller::Lag_error"] < 0 ) |
    (df1_copia["pSvolFilm::CTRL_Position_controller::Lag_error"] > 3 )
).astype(int)

df1_copia["s2"].value_counts()
# Out:
# s2
# 0    1050585
# 1      12327
# Name: count, dtype: int64

# %%
df1_copia_a = df1_copia[ ( df1_copia['s1'] == 1 ) & ( df1_copia['s2'] == 0 ) ]

data_plot = df1_copia_a[['pCut::CTRL_Position_controller::Lag_error', 
                    'pSvolFilm::CTRL_Position_controller::Lag_error']].mean().reset_index()
data_plot.columns = ['Motor_sensor1_and_2', 'Error_Medio']

plt.figure(figsize=(8, 5))
#sns.barplot(data=data_plot, x='Motor_sensor1_and_2', y='Error_Medio', hue='Motor_sensor1_and_2', palette='viridis')
sns.barplot(data=data_plot, x='Motor_sensor1_and_2', y='Error_Medio', palette='viridis')
plt.title('Media de Error cuando solo falla el Motor de Corte (S1)')
plt.ylabel('Lag Error Promedio')
plt.xticks([0, 1], ['Motor Corte (S1)', 'Motor Film (S2)'])
plt.show()

import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import OrdinalEncoder

# === PREPARACIÓN DE LOS DATOS ===
X = df1_copia.drop('averia', axis=1)
X = X.drop('s1', axis=1)
X = X.drop('s2', axis=1)

Y = np.array(df1_copia[['mode']])

# Definir el orden explícitamente
encoder = OrdinalEncoder(
    categories=[['mode0', 'mode1', 'mode2', 'mode3', 'mode4', 'mode5', 'mode6', 'mode7', 'mode8']] 
)
X['mode'] = encoder.fit_transform(Y)

X.info()

#print(X_encoded)
print(df1_copia_a['mode'].unique())

# PCA 

# === PASO 1: Centrar (y escalar) ===
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("Media por columna:", X_scaled.mean(axis=0).round(3))
print("Desviación típica:", X_scaled.std(axis=0).round(3))

# === PASO 2: Matriz de covarianza ===

pca = PCA(n_components=9)
X_pca_sklearn = pca.fit_transform(X_scaled)
# Out:
# C:\Users\FUNDACION\AppData\Local\Temp\ipykernel_14368\3606790740.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data_plot, x='Motor_sensor1_and_2', y='Error_Medio', palette='viridis')
# <class 'pandas.DataFrame'>
# RangeIndex: 1062912 entries, 0 to 1062911
# Data columns (total 15 columns):
#  #   Column                                                Non-Null Count    Dtype
# ---  ------                                                --------------    -----
#  0   timestamp                                             1062912 non-null  float64
#  1   pCut::Motor_Torque                                    1062912 non-null  float64
#  2   pCut::CTRL_Position_controller::Lag_error             1062912 non-null  float64
#  3   pCut::CTRL_Position_controller::Actual_position       1062912 non-null  int64
# ...

# %%
# ENTRENAMIENTO DE MODELO DE CLASIFICACIÓN
# Out:
# Resultados con Sobremuestreo Aleatorio:
# Accuracy: 51.11%
# Precision: 50.49%
# Recall: 49.36%
# F1-Score: 49.92%
# AUC-ROC: 51.87%
#
# Resultados con SMOTE:
# Accuracy: 51.26%
# Precision: 50.65%
# Recall: 48.60%
# F1-Score: 49.60%
# AUC-ROC: 51.98%
#
# Resultados con Submuestreo Aleatorio:
# Accuracy: 51.16%
# Precision: 50.55%
# Recall: 48.53%
# F1-Score: 49.52%
# AUC-ROC: 51.90%
#
# Resultados con NearMiss:
# Accuracy: 51.24%
# Precision: 50.65%
# Recall: 47.70%
# F1-Score: 49.13%
# AUC-ROC: 51.91%
#
# El mejor método de balanceo es: Sobremuestreo Aleatorio con F1-Score: 49.92% y AUC-ROC: 51.87%
#
# Resultados con ajuste manual de hiperparámetros:
# Accuracy: 51.11%
# Precision: 50.49%
# Recall: 49.36%
# F1-Score: 49.92%
# AUC-ROC: 51.87%
#
# Resultados con ajuste automático de hiperparámetros:
# Mejores parámetros: {'C': 0.001, 'solver': 'lbfgs'}
# Mejor Accuracy en validación cruzada: 51.81%
# Accuracy: 52.33%
# Precision: 51.98%
# Recall: 44.98%
# F1-Score: 48.23%
# ...

# %%
# ENTRENAMIENTO DE MODELO DE CLASIFICACIÓN

# Importación de librerías para clasificación
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.metrics import classification_report
import numpy as np

y = df1_copia['averia']

# Bloque de código para clasificación
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

model = RandomForestClassifier(n_estimators=100, random_state=42)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
print(f"OOB Score: {model.oob_score_:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    107646
#            1       1.00      1.00      1.00    104937
#
#     accuracy                           1.00    212583
#    macro avg       1.00      1.00      1.00    212583
# weighted avg       1.00      1.00      1.00    212583
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 22
#      18
#      19 y_pred = model.predict(X_test)
#      20
#      21 print(classification_report(y_test, y_pred))
# ---> 22 print(f"OOB Score: {model.oob_score_:.4f}")
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'oob_score_'
